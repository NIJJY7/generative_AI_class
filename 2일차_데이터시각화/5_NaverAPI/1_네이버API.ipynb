# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "qm83FBIXGeZFWkhBTu3i"
client_secret = "6c1vpFYusZ"
encText = urllib.parse.quote("커피")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
#count 1 -> 101 -> 201
url = "https://openapi.naver.com/v1/search/blog?query=" + encText +"&start={count}&display=100" # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Thu, 28 Mar 2024 10:10:38 +0900",
# 	"total":41293300,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"핸드드립 맷돌<b>커피<\/b> 김해 삼계동카페 다반사",
# 			"link":"https:\/\/blog.naver.com\/1004ykw\/223395659112",
# 			"description":"맷돌<b>커피<\/b>가 있다고 해서 궁금했다. 게다가 핸드드립임. 특색 있는 카페가 가까이에 있어서 가보았다.... 맷돌<b>커피<\/b>라는것도 이색적이지만, 핸드드립이라 오랜만에 구경했다. 핸드드립이 원두의 맛보다 물의 온도... ",
# 			"bloggername":"너는 모르는 여자이야기",
# 			"bloggerlink":"blog.naver.com\/1004ykw",
# 			"postdate":"20240326"
# 		},
# 		{
# 			"title":"<b>커피<\/b>인 바리스타 원데이클래스 리뷰 국비지원교육",
# 			"link":"https:\/\/blog.naver.com\/renarenaworld\/223395188563",
# 			"description":"지난주에는 바리스타 학원에서 <b>커피<\/b> 원데이클래스 교육을 듣고 왔다. SCA국비지원이 되는 곳인데 물론... 위치 \/ 주차 <b>커피<\/b>인바리스타학원은 강서구에 위치해 있고, 화곡역 5번출구 바로 인근이다. 차를 가져가면... ",
# 			"bloggername":"레나레나 ✨ CEO가 취미고 공예가 본업이에요",
# 			"bloggerlink":"blog.naver.com\/renarenaworld",
# 			"postdate":"20240325"
# 		},
# 		{
# 			"title":"강릉 카페 이진리 \/ 시그니처 후추<b>커피<\/b> 대존맛",
# 			"link":"https:\/\/blog.naver.com\/hyuni2mail\/223397084072",
# 			"description":"중에서 <b>커피<\/b>가 맛있는 곳, 특히 시그니처인 후추<b>커피<\/b>가 맛있는 카페인 강릉 이진리 카페를 찾아갔어요 :) 요즘 떠오르는 강릉 맛집이라는 감자유원지 후기가 궁금하시다면 위 링크 클릭해서 같이 보셔도... ",
# 			"bloggername":"혀니의 리뷰톡톡",
# 			"bloggerlink":"blog.naver.com\/hyuni2mail",
# 			"postdate":"20240328"
# 		},
# 		{
# 			"title":"포항카페 : 바르벳 효리단길(브런치메뉴.드립<b>커피<\/b>)",
# 			"link":"https:\/\/blog.naver.com\/lovelyram2\/223395703716",
# 			"description":"브런치 메뉴도 보이고 <b>커피<\/b>와 음료종류도있었는데 금액이 착합니다 : ) 드립<b>커피<\/b> HOT 4.5 드립<b>커피<\/b> ICE 4.5 말차라떼 5.0 당근케이크 7.5 세명 온거 아님.. 둘이 온거임.. : ) ㅋㅋㅋ 원래 둘다 아아 시키는데 저는 이... ",
# 			"bloggername":"○◑●동그람이의 여행로그●◐○",
# 			"bloggerlink":"blog.naver.com\/lovelyram2",
# 			"postdate":"20240326"
# 		},
# 		{
# 			"title":"2024 코엑스 <b>커피<\/b>엑스포 사전예약 관람 후기",
# 			"link":"https:\/\/blog.naver.com\/red9house\/223397551040",
# 			"description":"점심을 딤딤섬에서 맛나게 먹고 <b>커피<\/b>엑스포로 출동했어요. 2월에 사전등록 할인해서 1인당 2,000원에... <b>커피<\/b>엑스포는 <b>커피<\/b>산업 트렌드를 한눈에 볼 수 있고 <b>커피<\/b> 머신을 비롯한 각종 장비와 디저트까지... ",
# 			"bloggername":"감사한 여유미님의 블로그",
# 			"bloggerlink":"blog.naver.com\/red9house",
# 			"postdate":"20240327"
# 		},
# 		{
# 			"title":"후쿠오카 텐진 카페 <b>커피<\/b> 푸딩 맛집 킷사텐 코히샤노다",
# 			"link":"https:\/\/blog.naver.com\/seul__look\/223394511125",
# 			"description":"킷사텐이예요 <b>커피<\/b> 푸딩으로 한국에서 유명세를 타고 있는 카페 그 외에도 다양한 디저트가 있어요.... 입고 <b>커피<\/b>를 내리는 모습이 멋져요 코히샤노다는 직원들 일하는 모습 촬영 불가예요. 그냥 본인 테이블... ",
# 			"bloggername":"I LIKE IT",
# 			"bloggerlink":"blog.naver.com\/seul__look",
# 			"postdate":"20240325"
# 		},
# 		{
# 			"title":"드립<b>커피<\/b> 방법 내리는법 과테말라 스페셜티 원두",
# 			"link":"https:\/\/blog.naver.com\/hwain_ci\/223393096187",
# 			"description":"드립<b>커피<\/b> 방법 내리는법 과테말라 스페셜티 원두 밖에서 <b>커피<\/b> 마시는 걸 좋아하긴 하지만 가성비가 떨어져서 보통 집에서 드립<b>커피<\/b> 방법을 이용해 마시고 있는데요 드립<b>커피<\/b> 내리는법이라고 해도 제... ",
# 			"bloggername":"다이어트 레시피 만드는 이트샤",
# 			"bloggerlink":"blog.naver.com\/hwain_ci",
# 			"postdate":"20240324"
# 		},
# 		{
# 			"title":"<b>커피<\/b>창업 성공을 위한 발판 마련하려면",
# 			"link":"https:\/\/blog.naver.com\/kikiiyy\/223394996784",
# 			"description":"처음 <b>커피<\/b>창업을 고려하시는 분들이라면 사업 자체를 처음 시도해보는 경우가 많은데요. 자본이 충분한... 일반적으로 <b>커피<\/b>창업을 하게 되면 다양한 연령층의 고객을 만나게 됩니다. 10대부터 시작되는 젊은 세대... ",
# 			"bloggername":"CONDA",
# 			"bloggerlink":"blog.naver.com\/kikiiyy",
# 			"postdate":"20240325"
# 		},
# 		{
# 			"title":"<b>커피<\/b>한약방ㆍ혜민당",
# 			"link":"https:\/\/blog.naver.com\/save_space\/223380204517",
# 			"description":"우리나라에서 맨 먼저 <b>커피<\/b>를 맛본 이로 알려진 고종 그가 살았던 시절을 모티프로 삼아 꾸며 예스러운 공간이 인상적인 <b>커피<\/b>한약방 2024.02.21 지금은 낡아서 간판의 글자가 다 떨어지고 있지만 여기까지 갔으면... ",
# 			"bloggername":"끌림:둘러보기",
# 			"bloggerlink":"blog.naver.com\/save_space",
# 			"postdate":"20240311"
# 		},
# 		{
# 			"title":"특별한 핸드드립 <b>커피<\/b> 춘천 남춘천역카페 에딧플레이버",
# 			"link":"https:\/\/blog.naver.com\/beautymix118\/223396397831",
# 			"description":"오늘 아주 특별한 핸드드립 <b>커피<\/b>맛을 맛볼 수 있는 카페에 다녀왔어요. 바로 춘천 남춘천역카페... 카페를 찾아주는 분들에게 각자의 취향에 맞는 <b>커피<\/b>를 제공하고 연결해 준다는 편집이라는 키워드로 만들어진... ",
# 			"bloggername":"푸드문의 행복한 채식 친환경 라이프",
# 			"bloggerlink":"blog.naver.com\/beautymix118",
# 			"postdate":"20240327"
# 		}
# 	]
# }

# %%
import json
text_data = response_body.decode('utf-8')
print(text_data)
json_data = json.loads(text_data) #json 형태를 텍스트로
print(json_data)
print(type(json_data))
# Out:
# {
# 	"lastBuildDate":"Thu, 28 Mar 2024 10:10:38 +0900",
# 	"total":41293300,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"핸드드립 맷돌<b>커피<\/b> 김해 삼계동카페 다반사",
# 			"link":"https:\/\/blog.naver.com\/1004ykw\/223395659112",
# 			"description":"맷돌<b>커피<\/b>가 있다고 해서 궁금했다. 게다가 핸드드립임. 특색 있는 카페가 가까이에 있어서 가보았다.... 맷돌<b>커피<\/b>라는것도 이색적이지만, 핸드드립이라 오랜만에 구경했다. 핸드드립이 원두의 맛보다 물의 온도... ",
# 			"bloggername":"너는 모르는 여자이야기",
# 			"bloggerlink":"blog.naver.com\/1004ykw",
# 			"postdate":"20240326"
# 		},
# 		{
# 			"title":"<b>커피<\/b>인 바리스타 원데이클래스 리뷰 국비지원교육",
# 			"link":"https:\/\/blog.naver.com\/renarenaworld\/223395188563",
# 			"description":"지난주에는 바리스타 학원에서 <b>커피<\/b> 원데이클래스 교육을 듣고 왔다. SCA국비지원이 되는 곳인데 물론... 위치 \/ 주차 <b>커피<\/b>인바리스타학원은 강서구에 위치해 있고, 화곡역 5번출구 바로 인근이다. 차를 가져가면... ",
# 			"bloggername":"레나레나 ✨ CEO가 취미고 공예가 본업이에요",
# 			"bloggerlink":"blog.naver.com\/renarenaworld",
# 			"postdate":"20240325"
# 		},
# 		{
# 			"title":"강릉 카페 이진리 \/ 시그니처 후추<b>커피<\/b> 대존맛",
# 			"link":"https:\/\/blog.naver.com\/hyuni2mail\/223397084072",
# 			"description":"중에서 <b>커피<\/b>가 맛있는 곳, 특히 시그니처인 후추<b>커피<\/b>가 맛있는 카페인 강릉 이진리 카페를 찾아갔어요 :) 요즘 떠오르는 강릉 맛집이라는 감자유원지 후기가 궁금하시다면 위 링크 클릭해서 같이 보셔도... ",
# 			"bloggername":"혀니의 리뷰톡톡",
# 			"bloggerlink":"blog.naver.com\/hyuni2mail",
# 			"postdate":"20240328"
# 		},
# 		{
# 			"title":"포항카페 : 바르벳 효리단길(브런치메뉴.드립<b>커피<\/b>)",
# 			"link":"https:\/\/blog.naver.com\/lovelyram2\/223395703716",
# 			"description":"브런치 메뉴도 보이고 <b>커피<\/b>와 음료종류도있었는데 금액이 착합니다 : ) 드립<b>커피<\/b> HOT 4.5 드립<b>커피<\/b> ICE 4.5 말차라떼 5.0 당근케이크 7.5 세명 온거 아님.. 둘이 온거임.. : ) ㅋㅋㅋ 원래 둘다 아아 시키는데 저는 이... ",
# 			"bloggername":"○◑●동그람이의 여행로그●◐○",
# 			"bloggerlink":"blog.naver.com\/lovelyram2",
# 			"postdate":"20240326"
# 		},
# 		{
# 			"title":"2024 코엑스 <b>커피<\/b>엑스포 사전예약 관람 후기",
# 			"link":"https:\/\/blog.naver.com\/red9house\/223397551040",
# 			"description":"점심을 딤딤섬에서 맛나게 먹고 <b>커피<\/b>엑스포로 출동했어요. 2월에 사전등록 할인해서 1인당 2,000원에... <b>커피<\/b>엑스포는 <b>커피<\/b>산업 트렌드를 한눈에 볼 수 있고 <b>커피<\/b> 머신을 비롯한 각종 장비와 디저트까지... ",
# 			"bloggername":"감사한 여유미님의 블로그",
# 			"bloggerlink":"blog.naver.com\/red9house",
# 			"postdate":"20240327"
# 		},
# 		{
# 			"title":"후쿠오카 텐진 카페 <b>커피<\/b> 푸딩 맛집 킷사텐 코히샤노다",
# 			"link":"https:\/\/blog.naver.com\/seul__look\/223394511125",
# 			"description":"킷사텐이예요 <b>커피<\/b> 푸딩으로 한국에서 유명세를 타고 있는 카페 그 외에도 다양한 디저트가 있어요.... 입고 <b>커피<\/b>를 내리는 모습이 멋져요 코히샤노다는 직원들 일하는 모습 촬영 불가예요. 그냥 본인 테이블... ",
# 			"bloggername":"I LIKE IT",
# 			"bloggerlink":"blog.naver.com\/seul__look",
# 			"postdate":"20240325"
# 		},
# 		{
# 			"title":"드립<b>커피<\/b> 방법 내리는법 과테말라 스페셜티 원두",
# 			"link":"https:\/\/blog.naver.com\/hwain_ci\/223393096187",
# 			"description":"드립<b>커피<\/b> 방법 내리는법 과테말라 스페셜티 원두 밖에서 <b>커피<\/b> 마시는 걸 좋아하긴 하지만 가성비가 떨어져서 보통 집에서 드립<b>커피<\/b> 방법을 이용해 마시고 있는데요 드립<b>커피<\/b> 내리는법이라고 해도 제... ",
# 			"bloggername":"다이어트 레시피 만드는 이트샤",
# 			"bloggerlink":"blog.naver.com\/hwain_ci",
# 			"postdate":"20240324"
# 		},
# 		{
# 			"title":"<b>커피<\/b>창업 성공을 위한 발판 마련하려면",
# 			"link":"https:\/\/blog.naver.com\/kikiiyy\/223394996784",
# 			"description":"처음 <b>커피<\/b>창업을 고려하시는 분들이라면 사업 자체를 처음 시도해보는 경우가 많은데요. 자본이 충분한... 일반적으로 <b>커피<\/b>창업을 하게 되면 다양한 연령층의 고객을 만나게 됩니다. 10대부터 시작되는 젊은 세대... ",
# 			"bloggername":"CONDA",
# 			"bloggerlink":"blog.naver.com\/kikiiyy",
# 			"postdate":"20240325"
# 		},
# 		{
# 			"title":"<b>커피<\/b>한약방ㆍ혜민당",
# 			"link":"https:\/\/blog.naver.com\/save_space\/223380204517",
# 			"description":"우리나라에서 맨 먼저 <b>커피<\/b>를 맛본 이로 알려진 고종 그가 살았던 시절을 모티프로 삼아 꾸며 예스러운 공간이 인상적인 <b>커피<\/b>한약방 2024.02.21 지금은 낡아서 간판의 글자가 다 떨어지고 있지만 여기까지 갔으면... ",
# 			"bloggername":"끌림:둘러보기",
# 			"bloggerlink":"blog.naver.com\/save_space",
# 			"postdate":"20240311"
# 		},
# 		{
# 			"title":"특별한 핸드드립 <b>커피<\/b> 춘천 남춘천역카페 에딧플레이버",
# 			"link":"https:\/\/blog.naver.com\/beautymix118\/223396397831",
# 			"description":"오늘 아주 특별한 핸드드립 <b>커피<\/b>맛을 맛볼 수 있는 카페에 다녀왔어요. 바로 춘천 남춘천역카페... 카페를 찾아주는 분들에게 각자의 취향에 맞는 <b>커피<\/b>를 제공하고 연결해 준다는 편집이라는 키워드로 만들어진... ",
# 			"bloggername":"푸드문의 행복한 채식 친환경 라이프",
# 			"bloggerlink":"blog.naver.com\/beautymix118",
# 			"postdate":"20240327"
# 		}
# 	]
# }
# {'lastBuildDate': 'Thu, 28 Mar 2024 10:10:38 +0900', 'total': 41293300, 'start': 1, 'display': 10, 'items': [{'title': '핸드드립 맷돌<b>커피</b> 김해 삼계동카페 다반사', 'link': 'https://blog.naver.com/1004ykw/223395659112', 'description': '맷돌<b>커피</b>가 있다고 해서 궁금했다. 게다가 핸드드립임. 특색 있는 카페가 가까이에 있어서 가보았다.... 맷돌<b>커피</b>라는것도 이색적이지만, 핸드드립이라 오랜만에 구경했다. 핸드드립이 원두의 맛보다 물의 온도... ', 'bloggername': '너는 모르는 여자이야기', 'bloggerlink': 'blog.naver.com/1004ykw', 'postdate': '20240326'}, {'title': '<b>커피</b>인 바리스타 원데이클래스 리뷰 국비지원교육', 'link': 'https://blog.naver.com/renarenaworld/223395188563', 'description': '지난주에는 바리스타 학원에서 <b>커피</b> 원데이클래스 교육을 듣고 왔다. SCA국비지원이 되는 곳인데 물론... 위치 / 주차 <b>커피</b>인바리스타학원은 강서구에 위치해 있고, 화곡역 5번출구 바로 인근이다. 차를 가져가면... ', 'bloggername': '레나레나 ✨ CEO가 취미고 공예가 본업이에요', 'bloggerlink': 'blog.naver.com/renarenaworld', 'postdate': '20240325'}, {'title': '강릉 카페 이진리 / 시그니처 후추<b>커피</b> 대존맛', 'link': 'https://blog.naver.com/hyuni2mail/223397084072', 'description': '중에서 <b>커피</b>가 맛있는 곳, 특히 시그니처인 후추<b>커피</b>가 맛있는 카페인 강릉 이진리 카페를 찾아갔어요 :) 요즘 떠오르는 강릉 맛집이라는 감자유원지 후기가 궁금하시다면 위 링크 클릭해서 같이 보셔도... ', 'bloggername': '혀니의 리뷰톡톡', 'bloggerlink': 'blog.naver.com/hyuni2mail', 'postdate': '20240328'}, {'title': '포항카페 : 바르벳 효리단길(브런치메뉴.드립<b>커피</b>)', 'link': 'https://blog.naver.com/lovelyram2/223395703716', 'description': '브런치 메뉴도 보이고 <b>커피</b>와 음료종류도있었는데 금액이 착합니다 : ) 드립<b>커피</b> HOT 4.5 드립<b>커피</b> ICE 4.5 말차라떼 5.0 당근케이크 7.5 세명 온거 아님.. 둘이 온거임.. : ) ㅋㅋㅋ 원래 둘다 아아 시키는데 저는 이... ', 'bloggername': '○◑●동그람이의 여행로그●◐○', 'bloggerlink': 'blog.naver.com/lovelyram2', 'postdate': '20240326'}, {'title': '2024 코엑스 <b>커피</b>엑스포 사전예약 관람 후기', 'link': 'https://blog.naver.com/red9house/223397551040', 'description': '점심을 딤딤섬에서 맛나게 먹고 <b>커피</b>엑스포로 출동했어요. 2월에 사전등록 할인해서 1인당 2,000원에... <b>커피</b>엑스포는 <b>커피</b>산업 트렌드를 한눈에 볼 수 있고 <b>커피</b> 머신을 비롯한 각종 장비와 디저트까지... ', 'bloggername': '감사한 여유미님의 블로그', 'bloggerlink': 'blog.naver.com/red9house', 'postdate': '20240327'}, {'title': '후쿠오카 텐진 카페 <b>커피</b> 푸딩 맛집 킷사텐 코히샤노다', 'link': 'https://blog.naver.com/seul__look/223394511125', 'description': '킷사텐이예요 <b>커피</b> 푸딩으로 한국에서 유명세를 타고 있는 카페 그 외에도 다양한 디저트가 있어요.... 입고 <b>커피</b>를 내리는 모습이 멋져요 코히샤노다는 직원들 일하는 모습 촬영 불가예요. 그냥 본인 테이블... ', 'bloggername': 'I LIKE IT', 'bloggerlink': 'blog.naver.com/seul__look', 'postdate': '20240325'}, {'title': '드립<b>커피</b> 방법 내리는법 과테말라 스페셜티 원두', 'link': 'https://blog.naver.com/hwain_ci/223393096187', 'description': '드립<b>커피</b> 방법 내리는법 과테말라 스페셜티 원두 밖에서 <b>커피</b> 마시는 걸 좋아하긴 하지만 가성비가 떨어져서 보통 집에서 드립<b>커피</b> 방법을 이용해 마시고 있는데요 드립<b>커피</b> 내리는법이라고 해도 제... ', 'bloggername': '다이어트 레시피 만드는 이트샤', 'bloggerlink': 'blog.naver.com/hwain_ci', 'postdate': '20240324'}, {'title': '<b>커피</b>창업 성공을 위한 발판 마련하려면', 'link': 'https://blog.naver.com/kikiiyy/223394996784', 'description': '처음 <b>커피</b>창업을 고려하시는 분들이라면 사업 자체를 처음 시도해보는 경우가 많은데요. 자본이 충분한... 일반적으로 <b>커피</b>창업을 하게 되면 다양한 연령층의 고객을 만나게 됩니다. 10대부터 시작되는 젊은 세대... ', 'bloggername': 'CONDA', 'bloggerlink': 'blog.naver.com/kikiiyy', 'postdate': '20240325'}, {'title': '<b>커피</b>한약방ㆍ혜민당', 'link': 'https://blog.naver.com/save_space/223380204517', 'description': '우리나라에서 맨 먼저 <b>커피</b>를 맛본 이로 알려진 고종 그가 살았던 시절을 모티프로 삼아 꾸며 예스러운 공간이 인상적인 <b>커피</b>한약방 2024.02.21 지금은 낡아서 간판의 글자가 다 떨어지고 있지만 여기까지 갔으면... ', 'bloggername': '끌림:둘러보기', 'bloggerlink': 'blog.naver.com/save_space', 'postdate': '20240311'}, {'title': '특별한 핸드드립 <b>커피</b> 춘천 남춘천역카페 에딧플레이버', 'link': 'https://blog.naver.com/beautymix118/223396397831', 'description': '오늘 아주 특별한 핸드드립 <b>커피</b>맛을 맛볼 수 있는 카페에 다녀왔어요. 바로 춘천 남춘천역카페... 카페를 찾아주는 분들에게 각자의 취향에 맞는 <b>커피</b>를 제공하고 연결해 준다는 편집이라는 키워드로 만들어진... ', 'bloggername': '푸드문의 행복한 채식 친환경 라이프', 'bloggerlink': 'blog.naver.com/beautymix118', 'postdate': '20240327'}]}
# <class 'dict'>

# %%
json_data["items"]
# Out:
# [{'title': '핸드드립 맷돌<b>커피</b> 김해 삼계동카페 다반사',
#   'link': 'https://blog.naver.com/1004ykw/223395659112',
#   'description': '맷돌<b>커피</b>가 있다고 해서 궁금했다. 게다가 핸드드립임. 특색 있는 카페가 가까이에 있어서 가보았다.... 맷돌<b>커피</b>라는것도 이색적이지만, 핸드드립이라 오랜만에 구경했다. 핸드드립이 원두의 맛보다 물의 온도... ',
#   'bloggername': '너는 모르는 여자이야기',
#   'bloggerlink': 'blog.naver.com/1004ykw',
#   'postdate': '20240326'},
#  {'title': '<b>커피</b>인 바리스타 원데이클래스 리뷰 국비지원교육',
#   'link': 'https://blog.naver.com/renarenaworld/223395188563',
#   'description': '지난주에는 바리스타 학원에서 <b>커피</b> 원데이클래스 교육을 듣고 왔다. SCA국비지원이 되는 곳인데 물론... 위치 / 주차 <b>커피</b>인바리스타학원은 강서구에 위치해 있고, 화곡역 5번출구 바로 인근이다. 차를 가져가면... ',
#   'bloggername': '레나레나 ✨ CEO가 취미고 공예가 본업이에요',
#   'bloggerlink': 'blog.naver.com/renarenaworld',
#   'postdate': '20240325'},
#  {'title': '강릉 카페 이진리 / 시그니처 후추<b>커피</b> 대존맛',
#   'link': 'https://blog.naver.com/hyuni2mail/223397084072',
#   'description': '중에서 <b>커피</b>가 맛있는 곳, 특히 시그니처인 후추<b>커피</b>가 맛있는 카페인 강릉 이진리 카페를 찾아갔어요 :) 요즘 떠오르는 강릉 맛집이라는 감자유원지 후기가 궁금하시다면 위 링크 클릭해서 같이 보셔도... ',
#   'bloggername': '혀니의 리뷰톡톡',
#   'bloggerlink': 'blog.naver.com/hyuni2mail',
#   'postdate': '20240328'},
#  {'title': '포항카페 : 바르벳 효리단길(브런치메뉴.드립<b>커피</b>)',
#   'link': 'https://blog.naver.com/lovelyram2/223395703716',
#   'description': '브런치 메뉴도 보이고 <b>커피</b>와 음료종류도있었는데 금액이 착합니다 : ) 드립<b>커피</b> HOT 4.5 드립<b>커피</b> ICE 4.5 말차라떼 5.0 당근케이크 7.5 세명 온거 아님.. 둘이 온거임.. : ) ㅋㅋㅋ 원래 둘다 아아 시키는데 저는 이... ',
#   'bloggername': '○◑●동그람이의 여행로그●◐○',
#   'bloggerlink': 'blog.naver.com/lovelyram2',
#   'postdate': '20240326'},
#  {'title': '2024 코엑스 <b>커피</b>엑스포 사전예약 관람 후기',
#   'link': 'https://blog.naver.com/red9house/223397551040',
#   'description': '점심을 딤딤섬에서 맛나게 먹고 <b>커피</b>엑스포로 출동했어요. 2월에 사전등록 할인해서 1인당 2,000원에... <b>커피</b>엑스포는 <b>커피</b>산업 트렌드를 한눈에 볼 수 있고 <b>커피</b> 머신을 비롯한 각종 장비와 디저트까지... ',
#   'bloggername': '감사한 여유미님의 블로그',
#   'bloggerlink': 'blog.naver.com/red9house',
#   'postdate': '20240327'},
#  {'title': '후쿠오카 텐진 카페 <b>커피</b> 푸딩 맛집 킷사텐 코히샤노다',
#   'link': 'https://blog.naver.com/seul__look/223394511125',
#   'description': '킷사텐이예요 <b>커피</b> 푸딩으로 한국에서 유명세를 타고 있는 카페 그 외에도 다양한 디저트가 있어요.... 입고 <b>커피</b>를 내리는 모습이 멋져요 코히샤노다는 직원들 일하는 모습 촬영 불가예요. 그냥 본인 테이블... ',
#   'bloggername': 'I LIKE IT',
#   'bloggerlink': 'blog.naver.com/seul__look',
#   'postdate': '20240325'},
#  {'title': '드립<b>커피</b> 방법 내리는법 과테말라 스페셜티 원두',
#   'link': 'https://blog.naver.com/hwain_ci/223393096187',
#   'description': '드립<b>커피</b> 방법 내리는법 과테말라 스페셜티 원두 밖에서 <b>커피</b> 마시는 걸 좋아하긴 하지만 가성비가 떨어져서 보통 집에서 드립<b>커피</b> 방법을 이용해 마시고 있는데요 드립<b>커피</b> 내리는법이라고 해도 제... ',
#   'bloggername': '다이어트 레시피 만드는 이트샤',
#   'bloggerlink': 'blog.naver.com/hwain_ci',
#   'postdate': '20240324'},
#  {'title': '<b>커피</b>창업 성공을 위한 발판 마련하려면',
#   'link': 'https://blog.naver.com/kikiiyy/223394996784',
#   'description': '처음 <b>커피</b>창업을 고려하시는 분들이라면 사업 자체를 처음 시도해보는 경우가 많은데요. 자본이 충분한... 일반적으로 <b>커피</b>창업을 하게 되면 다양한 연령층의 고객을 만나게 됩니다. 10대부터 시작되는 젊은 세대... ',
#   'bloggername': 'CONDA',
#   'bloggerlink': 'blog.naver.com/kikiiyy',
#   'postdate': '20240325'},
#  {'title': '<b>커피</b>한약방ㆍ혜민당',
#   'link': 'https://blog.naver.com/save_space/223380204517',
#   'description': '우리나라에서 맨 먼저 <b>커피</b>를 맛본 이로 알려진 고종 그가 살았던 시절을 모티프로 삼아 꾸며 예스러운 공간이 인상적인 <b>커피</b>한약방 2024.02.21 지금은 낡아서 간판의 글자가 다 떨어지고 있지만 여기까지 갔으면... ',
#   'bloggername': '끌림:둘러보기',
#   'bloggerlink': 'blog.naver.com/save_space',
#   'postdate': '20240311'},
#  {'title': '특별한 핸드드립 <b>커피</b> 춘천 남춘천역카페 에딧플레이버',
#   'link': 'https://blog.naver.com/beautymix118/223396397831',
#   'description': '오늘 아주 특별한 핸드드립 <b>커피</b>맛을 맛볼 수 있는 카페에 다녀왔어요. 바로 춘천 남춘천역카페... 카페를 찾아주는 분들에게 각자의 취향에 맞는 <b>커피</b>를 제공하고 연결해 준다는 편집이라는 키워드로 만들어진... ',
#   'bloggername': '푸드문의 행복한 채식 친환경 라이프',
#   'bloggerlink': 'blog.naver.com/beautymix118',
#   'postdate': '20240327'}]

# %%
result_data = []
for x in json_data["items"]:
    print(x['description'])
    resuolt_data.append(x['description'])
# Out:
# 맷돌<b>커피</b>가 있다고 해서 궁금했다. 게다가 핸드드립임. 특색 있는 카페가 가까이에 있어서 가보았다.... 맷돌<b>커피</b>라는것도 이색적이지만, 핸드드립이라 오랜만에 구경했다. 핸드드립이 원두의 맛보다 물의 온도...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 for x in json_data["items"]:
#       3     print(x['description'])
# ----> 4     resuolt_data.append(x['description'])
#
# NameError: name 'resuolt_data' is not defined
